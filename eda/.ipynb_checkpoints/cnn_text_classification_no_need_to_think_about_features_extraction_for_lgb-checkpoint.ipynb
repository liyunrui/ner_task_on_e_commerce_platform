# %%
import pandas as pd
import numpy as np
import os
import gc
import sys
from tqdm import tqdm
sys.path.append('../brand_detector/preprocessing')
from clean_helpers import clean_name_for_word_embedding

# %% [markdown]
# # loading raw data

# %%
output_dir = '../brand_detector/data/preprocessed'

personal_care_and_beauty_shopee_df = pd.read_csv(os.path.join(output_dir, 'personal_care_and_beauty.csv'))
beauty_amazon_df = pd.read_csv(os.path.join(output_dir, 'beauty_amazon.csv'))
# configuration of shopee data: train/val/test = 35/15/50 (0,1,2)
train = pd.concat([beauty_amazon_df, personal_care_and_beauty_shopee_df[personal_care_and_beauty_shopee_df.is_valid == 0]], axis = 0)
val = personal_care_and_beauty_shopee_df[personal_care_and_beauty_shopee_df.is_valid == 1]
test = personal_care_and_beauty_shopee_df[personal_care_and_beauty_shopee_df.is_valid == 2]
del personal_care_and_beauty_shopee_df, beauty_amazon_df
# preprocessing
train['eval_set'] = ['train' for i in range(len(train))] 
val['eval_set'] = ['val' for i in range(len(val))] 
test['eval_set'] = ['test' for i in range(len(test))] 
train.drop(['is_valid'], axis =1, inplace = True)
val.drop(['is_valid'], axis =1, inplace = True)
test.drop(['is_valid'], axis =1, inplace = True)

print ('train', train.shape)
print ('val', val.shape)
print ('test', test.shape)
# all_df
all_df = pd.concat([train, val, test], axis = 0)
del train, test, val
gc.collect()
all_df.eval_set.value_counts()
# Out:
# train (836369, 4)
# val (8300, 4)
# test (21508, 4)
# train    836369
# test      21508
# val        8300
# Name: eval_set, dtype: int64

# %% [markdown]
# # pre-trained word-embedding

# %%
word_embedding_path = '/data/ID_large_wordvec_300_2.h5'
word2vec = pd.read_hdf(word_embedding_path)
# get word_to_id
word_to_id = {word: int(i+1) for i, word in enumerate(word2vec.word.tolist())}
# check
assert word_to_id['dan'] == 1, 'wrong in our dict mapping word to id'
assert word_to_id['di'] == 2, 'wrong in our dict mapping word to id'
assert word_to_id['yang'] == 3, 'wrong in our dict mapping word to id'

# %%
word2vec.head()
# Out:
#     word     dim_1     dim_2     dim_3     dim_4     dim_5     dim_6  \
# 0    dan  0.712676  2.387824 -2.937458  5.594606  1.196547  3.567468
# 1     di  1.646574  3.004994 -2.030986  1.284245  2.100287  0.033384
# 2   yang  3.893595  1.641351 -4.073985  7.351041  0.277348  3.169405
# 3   kami  4.253416 -1.777752 -4.561904  1.851718  0.782603  2.520426
# 4  untuk -3.492490  3.062385  1.732885  6.494920  1.681367  1.559415
#
#       dim_7     dim_8     dim_9    ...      dim_291   dim_292   dim_293  \
# 0 -0.333335 -1.570036 -1.445439    ...    -2.644627  0.048757  3.511451
# 1  0.991525  0.005785  0.410926    ...     1.630286 -5.025796  1.855228
# 2  1.772519 -1.548425 -3.901118    ...    -2.928375 -3.055444  3.708488
# 3  0.912112 -1.305857 -2.840159    ...    -2.663830 -8.415740  3.040092
# 4 -0.851074 -0.963648 -1.843624    ...    -4.281300 -2.645144 -0.548235
#
#     dim_294   dim_295   dim_296   dim_297   dim_298   dim_299   dim_300
# 0 -0.651203  2.474551 -0.118684  1.047346  2.676099 -3.377923  4.213373
# 1  1.364514  0.259180  2.906763 -2.368078 -1.652482 -5.045381  1.621557
# 2 -0.407081  2.588052 -0.101883 -0.059166 -0.397024 -0.894873  4.231138
# 3  1.991707  1.335176  3.994257  4.258120 -0.209764  1.378407  0.395307
# 4 -1.230889 -0.314143  0.879712  2.900071  0.650760 -5.747880  0.175559
#
# [5 rows x 301 columns]

# %%
def encode_word_to_idx(x, word_to_id):
    try:
        return word_to_id[x]
    except Exception:
        # way1: take all the word that do not exist in word space as another word
        return len(word_to_id)+1 
# preprocessing
all_df['clean_tokens'] = all_df.tokens.apply(lambda x: clean_name_for_word_embedding(x) if type(x)==str else x)
all_df['clean_tokens'] = all_df.clean_tokens.apply(lambda x: x.lower() if type(x)==str else x)
all_df['word_id'] = all_df.clean_tokens.apply( lambda x: encode_word_to_idx(x, word_to_id))
#
item_dict = {}
for i, i_n in enumerate(all_df.item_name.unique().tolist()):
    item_dict[i_n] = i+1
all_df['item_id'] = [item_dict[i] for i in all_df.item_name.tolist()]

# %% [markdown]
# # example

# %%
all_df[all_df.item_name.str.contains('NATURE REPUBLIC REAL SHEET MASK')]
# Out:
#                                   item_name    tokens  is_brand eval_set  \
# 30394       NATURE REPUBLIC REAL SHEET MASK    NATURE         2     test
# 30395       NATURE REPUBLIC REAL SHEET MASK  REPUBLIC         1     test
# 30396       NATURE REPUBLIC REAL SHEET MASK      REAL         0     test
# 30397       NATURE REPUBLIC REAL SHEET MASK     SHEET         0     test
# 30398       NATURE REPUBLIC REAL SHEET MASK      MASK         0     test
# 30399  NATURE REPUBLIC REAL SHEET MASK 23gr    NATURE         2     test
# 30400  NATURE REPUBLIC REAL SHEET MASK 23gr  REPUBLIC         1     test
# 30401  NATURE REPUBLIC REAL SHEET MASK 23gr      REAL         0     test
# 30402  NATURE REPUBLIC REAL SHEET MASK 23gr     SHEET         0     test
# 30403  NATURE REPUBLIC REAL SHEET MASK 23gr      MASK         0     test
# 30404  NATURE REPUBLIC REAL SHEET MASK 23gr      23gr         0     test
# 50495      NATURE REPUBLIC REAL SHEET MASK     NATURE         2     test
# 50496      NATURE REPUBLIC REAL SHEET MASK   REPUBLIC         1     test
# 50497      NATURE REPUBLIC REAL SHEET MASK       REAL         0     test
# 50498      NATURE REPUBLIC REAL SHEET MASK      SHEET         0     test
# 50499      NATURE REPUBLIC REAL SHEET MASK       MASK         0     test
#
#       clean_tokens  word_id  item_id
# 30394       nature     4682    92823
# 30395     republic    11412    92823
# 30396         real      653    92823
# 30397        sheet     5776    92823
# 30398         mask     2290    92823
# 30399       nature     4682    92824
# 30400     republic    11412    92824
# 30401         real      653    92824
# 30402        sheet     5776    92824
# 30403         mask     2290    92824
# 30404         23gr   112141    92824
# 50495       nature     4682    93906
# 50496     republic    11412    93906
# 50497         real      653    93906
# 50498        sheet     5776    93906
# 50499         mask     2290    93906

# %% [markdown]
# # prepare_training_data
#
# # output:
# # -item_id: for creating own item_embedding
# # -word_id: for matching word_embedding
# # -final_states:

# %%
def pad_1d(array, max_len):
    array = array[:max_len]
    length = len(array)
    padded = array + [0]*(max_len - len(array))
    return padded, length

#-------------------
# setting
#-------------------
TRUNCATED = False
num_sentences = all_df['item_name'].nunique()
seq_len_distribution = all_df.head(100).groupby('item_name').tokens.apply( lambda x : len(x.tolist())).to_frame('seq_len').reset_index()

if TRUNCATED == False:
    max_seq_length = seq_len_distribution.seq_len.max()
else:
    max_seq_length = 100
#-------------------
# output
#-------------------
print ('number of sequences : {}'.format(num_sentences))
# 1-D
eval_set = np.zeros(shape=[num_sentences], dtype='S5')
item_id = np.zeros(shape=[num_sentences], dtype=np.int32)
history_length = np.zeros(shape=[num_sentences], dtype=np.int8)
# 2-D
word_id = np.zeros(shape=[num_sentences, max_seq_length], dtype=np.int32)
label = np.zeros(shape=[num_sentences, max_seq_length], dtype=np.int8)
i = 0
for ix, df in tqdm(all_df.head(50).groupby('item_name')):
    # 1-d
    eval_set[i] = df['eval_set'].iloc[0]
    item_id[i] = df['item_id'].iloc[0]
    # 2-d
    word_id[i, :], history_length[i] = pad_1d(list(map(int, df['word_id'])), 
                                              max_len = max_seq_length)
    label[i, :], _ = pad_1d(list(map(int, df['is_brand'])), 
                                              max_len = max_seq_length)
    i += 1
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#
#
#
# 100%|██████████| 6/6 [00:00<00:00, 1199.23it/s]
# number of sequences : 93909

# %%
all_df
# Out:
#                                                item_name         tokens  \
# 0              #1 All Systems 3-D Volumizing Spray-12 Oz             #1
# 1              #1 All Systems 3-D Volumizing Spray-12 Oz            All
# 2              #1 All Systems 3-D Volumizing Spray-12 Oz        Systems
# 3              #1 All Systems 3-D Volumizing Spray-12 Oz            3-D
# 4              #1 All Systems 3-D Volumizing Spray-12 Oz     Volumizing
# 5              #1 All Systems 3-D Volumizing Spray-12 Oz       Spray-12
# 6              #1 All Systems 3-D Volumizing Spray-12 Oz             Oz
# 7      #1 Black - Alfaparf Color Wear Tone Hair Dye C...             #1
# 8      #1 Black - Alfaparf Color Wear Tone Hair Dye C...          Black
# 9      #1 Black - Alfaparf Color Wear Tone Hair Dye C...              -
# 10     #1 Black - Alfaparf Color Wear Tone Hair Dye C...       Alfaparf
# 11     #1 Black - Alfaparf Color Wear Tone Hair Dye C...          Color
# 12     #1 Black - Alfaparf Color Wear Tone Hair Dye C...           Wear
# 13     #1 Black - Alfaparf Color Wear Tone Hair Dye C...           Tone
# 14     #1 Black - Alfaparf Color Wear Tone Hair Dye C...           Hair
# 15     #1 Black - Alfaparf Color Wear Tone Hair Dye C...            Dye
# 16     #1 Black - Alfaparf Color Wear Tone Hair Dye C...          Color
# 17     #1 Black - Alfaparf Color Wear Tone Hair Dye C...           60mL
# 18      #100 Strip False Eyelashes by Red Cherry 6 Pairs           #100
# 19      #100 Strip False Eyelashes by Red Cherry 6 Pairs          Strip
# 20      #100 Strip False Eyelashes by Red Cherry 6 Pairs          False
# 21      #100 Strip False Eyelashes by Red Cherry 6 Pairs      Eyelashes
# 22      #100 Strip False Eyelashes by Red Cherry 6 Pairs             by
# 23      #100 Strip False Eyelashes by Red Cherry 6 Pairs            Red
# 24      #100 Strip False Eyelashes by Red Cherry 6 Pairs         Cherry
# 25      #100 Strip False Eyelashes by Red Cherry 6 Pairs              6
# 26      #100 Strip False Eyelashes by Red Cherry 6 Pairs          Pairs
# 27      #119 Strip False Eyelashes by Red Cherry 6 Pairs           #119
# 28      #119 Strip False Eyelashes by Red Cherry 6 Pairs          Strip
# 29      #119 Strip False Eyelashes by Red Cherry 6 Pairs          False
# ...                                                  ...            ...
# 50491         NATURE REPUBLIC REAL NATURE HYDROGEL MASK            REAL
# 50492         NATURE REPUBLIC REAL NATURE HYDROGEL MASK          NATURE
# 50493         NATURE REPUBLIC REAL NATURE HYDROGEL MASK        HYDROGEL
# 50494         NATURE REPUBLIC REAL NATURE HYDROGEL MASK            MASK
# 50495                   NATURE REPUBLIC REAL SHEET MASK          NATURE
# 50496                   NATURE REPUBLIC REAL SHEET MASK        REPUBLIC
# 50497                   NATURE REPUBLIC REAL SHEET MASK            REAL
# 50498                   NATURE REPUBLIC REAL SHEET MASK           SHEET
# 50499                   NATURE REPUBLIC REAL SHEET MASK            MASK
# 50514   Freeman Detox Charcoal Black Sugar Mud Mask M...        Freeman
# 50515   Freeman Detox Charcoal Black Sugar Mud Mask M...          Detox
# 50516   Freeman Detox Charcoal Black Sugar Mud Mask M...       Charcoal
# 50517   Freeman Detox Charcoal Black Sugar Mud Mask M...          Black
# 50518   Freeman Detox Charcoal Black Sugar Mud Mask M...          Sugar
# 50519   Freeman Detox Charcoal Black Sugar Mud Mask M...            Mud
# 50520   Freeman Detox Charcoal Black Sugar Mud Mask M...           Mask
# 50521   Freeman Detox Charcoal Black Sugar Mud Mask M...         Masker
# 50522   Freeman Detox Charcoal Black Sugar Mud Mask M...  Super-Dupenya
# 50523   Freeman Detox Charcoal Black Sugar Mud Mask M...       Glamglow
# 50524   Freeman Detox Charcoal Black Sugar Mud Mask M...       Supermud
# 50525   Freeman Detox Charcoal Black Sugar Mud Mask M...       Original
# 50526  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...          READY
# 50527  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...          STOCK
# 50528  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...        FREEMAN
# 50529  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...         TRAVEL
# 50530  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...           SIZE
# 50531  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...         SACHET
# 50532  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...           15ML
# 50533  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...            ALL
# 50534  READY STOCK FREEMAN TRAVEL SIZE SACHET 15ML AL...       VARIANTS
#
#        is_brand eval_set  clean_tokens  word_id  item_id
# 0             2    train             1        7        0
# 1             1    train           all      270        0
# 2             1    train       systems     8858        0
# 3             0    train            3d     1127        0
# 4             0    train    volumizing    22163        0
# 5             0    train       spray12  6629250        0
# 6             0    train            oz     2706        0
# 7             0    train             1        7        1
# 8             0    train         black       86        1
# 9             0    train                6629250        1
# 10            2    train      alfaparf    74162        1
# 11            0    train         color      421        1
# 12            0    train          wear     2783        1
# 13            0    train          tone     2607        1
# 14            0    train          hair     1241        1
# 15            0    train           dye    12650        1
# 16            0    train         color      421        1
# 17            0    train          60ml     3593        1
# 18            0    train           100       28        2
# 19            0    train         strip     2326        2
# 20            0    train         false    17084        2
# 21            0    train     eyelashes    15733        2
# 22            0    train            by      532        2
# 23            2    train           red      445        2
# 24            1    train        cherry     4544        2
# 25            0    train             6       67        2
# 26            0    train         pairs    11682        2
# 27            0    train           119     9617        3
# 28            0    train         strip     2326        3
# 29            0    train         false    17084        3
# ...         ...      ...           ...      ...      ...
# 50491         0     test          real      653    93905
# 50492         0     test        nature     4682    93905
# 50493         0     test      hydrogel    25602    93905
# 50494         0     test          mask     2290    93905
# 50495         2     test        nature     4682    93906
# 50496         1     test      republic    11412    93906
# 50497         0     test          real      653    93906
# 50498         0     test         sheet     5776    93906
# 50499         0     test          mask     2290    93906
# 50514         2     test       freeman    44862    93907
# 50515         0     test         detox     6201    93907
# 50516         0     test      charcoal     7910    93907
# 50517         0     test         black       86    93907
# 50518         0     test         sugar     5314    93907
# 50519         0     test           mud     7165    93907
# 50520         0     test          mask     2290    93907
# 50521         0     test        masker     1579    93907
# 50522         0     test  superdupenya  6629250    93907
# 50523         0     test      glamglow    21564    93907
# 50524         0     test      supermud    51281    93907
# 50525         0     test      original       34    93907
# 50526         0     test         ready       26    93908
# 50527         0     test         stock       60    93908
# 50528         2     test       freeman    44862    93908
# 50529         0     test        travel     1306    93908
# 50530         0     test          size       29    93908
# 50531         0     test        sachet     2365    93908
# 50532         0     test          15ml     9005    93908
# 50533         0     test           all      270    93908
# 50534         0     test      variants    39205    93908
#
# [866177 rows x 7 columns]

# %%
# get_input_sequences
def get_input_sequences():

# %% [markdown]
# # model architecture: https://git.garena.com/shopee-ds/Category-Suggestion/blob/master/model_train/deepmodel/core/tasks/cnn_training.py
